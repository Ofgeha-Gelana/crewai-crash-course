# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    tools=[SerperDevTool()],
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of year 2026.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  6fca1d8f-54fd-4b42-968c-7896037c01e5                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.           │
# │  ID: 185fd182-718d-46c7-8913-f1c8d768c415                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Args: {'search_query': 'future of electric vehicles 2026 facts'}                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_the_internet_with_serper executed with result: {'searchParameters': {'q': 'future of electric vehicles 2026 facts', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Future EVs: Every Electric Vehicle Coming Soon - Car and D...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Output: {'searchParameters': {'q': 'future of electric vehicles 2026 facts', 'type': 'search', 'num': 10,      │
# │  'engine': 'google'}, 'organic': [{'title': 'Future EVs: Every Electric Vehicle Coming Soon - Car and Driver',  │
# │  'link': 'https://www.caranddriver.com/news/g29994375/future-electric-cars-trucks/', 'snippet': 'Ferrari is     │
# │  readying its first fully electric car, which will debut in early 2026. Spy shots show a low-riding but         │
# │  crossover-like profile, and ...', 'position': 1}, {'title': 'The 16 Best EVs Coming in 2026 - WIRED', 'link':  │
# │  'https://www.wired.com/story/the-16-best-evs-coming-in-2026/', 'snippet': 'Range figures are impressive, with  │
# │  estimates extending to 400 miles. But how does it go? Fast: 1,133 hp and 0 to 62 mph in around 2.5 seconds,    │
# │  ...', 'position': 2}, {'title': 'Upcoming Electric Cars: 2026-2030 EVs | U.S. News', 'link':                   │
# │  'https://cars.usnews.com/cars-trucks/advice/future-electric-cars', 'snippet': 'The 2026 i3 is going to be      │
# │  reimagined as a small sedan, based on the Neue Klasse platform, which was showcased in a bold concept car in   │
# │  early 2023.', 'position': 3}, {'title': '3 Things You Should Know About EVs in 2026', 'link':                  │
# │  'https://whatissmartenergy.org/energy-blog/3-things-you-should-know-about-evs-in-2026', 'snippet': 'Worried    │
# │  about running out of power on a long trip? Good news: EV battery technology is improving fast. New models are  │
# │  coming out with longer ranges, letting ...', 'position': 4}, {'title': 'Electric Vehicles Have a Bumpy Road    │
# │  Ahead in 2026 - Bloomberg', 'link':                                                                            │
# │  'https://www.bloomberg.com/news/newsletters/2026-01-06/electric-vehicles-have-a-bumpy-road-ahead-in-2026',     │
# │  'snippet': "US sales in November plunged 41% from a year earlier, and the nation's annual passenger EV sales   │
# │  are forecast to contract 15% in 2026, ...", 'position': 5}, {'title': "It's 2026. Stop Buying New EVs.         │
# │  Tech-Hoard the One You Have", 'link': 'https://www.youtube.com/watch?v=Mq9IGNwErXw', 'snippet': '... future,   │
# │  it also brought increased anti-EV sentiment, policies designed to make electric vehicle ownership less         │
# │  appealing, and automakers ...', 'position': 6}, {'title': 'Every New EV Launching In 2026 In The U.S. -        │
# │  InsideEVs', 'link': 'https://insideevs.com/features/783999/every-new-electric-car-ev-2026/', 'snippet': "Over  │
# │  30 New EVs Are Launching In 2026. Here's What You Need To Know About Them. People seem to think the EV         │
# │  transition is going away. In reality ...", 'position': 7}, {'title': 'CES 2026: Top 10 EV trends that signal   │
# │  where electric cars are ...', 'link': 'https://interestingengineering.com/ces-2026/top-10-ev-tech-trends',     │
# │  'snippet': 'CES 2026: 10 EV technologies that could redefine the future intelligent driving · 1. Physical AI   │
# │  for vehicles · 2. Robotaxi platforms · 3. Software ...', 'position': 8, 'sitelinks': [{'title': '1. Physical   │
# │  Ai For Vehicles', 'link':                                                                                      │
# │  'https://interestingengineering.com/ces-2026/top-10-ev-tech-trends#:~:text=1.%20Physical%20AI%20for%20vehicle  │
# │  s'}, {'title': '2. Robotaxi Platforms', 'link':                                                                │
# │  'https://interestingengineering.com/ces-2026/top-10-ev-tech-trends#:~:text=2.%20Robotaxi%20platforms'},        │
# │  {'title': '6. Next-Gen Battery Tech And...', 'link':                                                           │
# │  'https://interestingengineering.com/ces-2026/top-10-ev-tech-trends#:~:text=6.%20Next%2Dgen%20battery%20tech%2  │
# │  0and%20charging'}]}, {'title': "What's Next for EVs? 5 Critical Trends Emerging in 2026 - GreyB", 'link':      │
# │  'https://greyb.com/blog/ev-industry-trends/', 'snippet': 'The EV industry trends for 2026 include enhanced     │
# │  electric vehicle charging technologies and batteries for better performance and longevity.', 'position': 9},   │
# │  {'title': 'EV realism is here. How automakers react in 2026 will be telling', 'link':                          │
# │  'https://www.cnbc.com/2025/12/23/evs-gm-ford-hyundai-tesla.html', 'snippet': 'PwC expects the EV industry to   │
# │  pick up toward the end of this decade, with EVs forecast to make up 19% of the U.S. industry by 2030. "As      │
# │  several ...', 'position': 10}], 'peopleAlsoAsk': [{'question': 'What is the EV market outlook for 2026?',      │
# │  'snippet': "US sales in November plunged 41% from a year earlier, and the nation's annual passenger EV sales   │
# │  are forecast to contract 15% in 2026, according to BNEF. Even in China, the world's top EV market, analysts    │
# │  are anticipating a slight slowdown in sales growth, due in part to narrowing government support for the        │
# │  industry.\nJan 6, 2026", 'title': 'Electric Vehicles Have a Bumpy Road Ahead in 2026 - Bloomberg', 'link':     │
# │  'https://www.bloomberg.com/news/newsletters/2026-01-06/electric-vehicles-have-a-bumpy-road-ahead-in-2026'},    │
# │  {'question': 'Where will EVs be in 5 years?', 'snippet': 'Across the rest of the world, electric car sales     │
# │  are expected to grow by over 30% to around 1.8 million. This would mean electric cars account for 6% of all    │
# │  car sales outside of the three major EV markets in 2025, up from 5% in 2024.', 'title': 'Trends in electric    │
# │  car markets – Global EV Outlook 2025 – Analysis - IEA', 'link':                                                │
# │  'https://www.iea.org/reports/global-ev-outlook-2025/trends-in-electric-car-markets-2'}, {'question': 'What is  │
# │  the real future of electric cars?', 'snippet': 'EVs remain attractive And demand for EVs could start to        │
# │  increase again if the cost of producing EVs, especially the batteries that make up a large part of the cost    │
# │  of electric vehicles, continues to drop. And virtually every automaker is announcing plans for less costly     │
# │  battery technology.', 'title': "The future for EVs in America looks grim. But the auto industry isn't ...",    │
# │  'link': 'https://www.cnn.com/2025/10/06/business/automakers-ev-plans'}], 'relatedSearches': [{'query': 'New    │
# │  electric cars 2026 usa'}, {'query': 'New electric cars 2026 Europe'}, {'query': 'New electric cars 2027'},     │
# │  {'query': 'Upcoming EVs 2026'}, {'query': 'Best 2026 electric cars'}, {'query': '2026 electric SUV'},          │
# │  {'query': 'New electric car company in usa'}, {'query': 'Best luxury electric cars 2026'}], 'credits': 1}      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   Ferrari is set to debut its first fully electric car in early 2026.                                        │
# │  *   New EV models coming out in 2026 are expected to have impressive range figures, with some estimates        │
# │  extending to 400 miles.                                                                                        │
# │  *   The 2026 BMW i3 will be reimagined as a small sedan, based on the Neue Klasse platform.                    │
# │  *   EV battery technology is rapidly improving, leading to new models with longer ranges.                      │
# │  *   Over 30 new EVs are launching in 2026 in the U.S.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.                 │
# │  Agent:                                                                                                         │
# │  Research Specialist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: 2f893dc6-3c38-4fb0-a2c4-ad2dc82da7ed                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is accelerating into an exciting new era, particularly in 2026! Get ready for  │
# │  groundbreaking innovations as over 30 new EVs are set to launch in the U.S. that year. Iconic brands are       │
# │  joining the charge, with Ferrari debuting its first fully electric car in early 2026. Battery technology is    │
# │  rapidly improving, promising impressive range figures, with some new models expected to reach up to 400 miles  │
# │  on a single charge. Even familiar names are getting a futuristic makeover, like the 2026 BMW i3, reimagined    │
# │  as a sleek small sedan built on the innovative Neue Klasse platform. The EV landscape is transforming          │
# │  rapidly!                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Write a 100-word blog post summary about The future of electrical vehicles using the facts from the research.  │
# │  Agent:                                                                                                         │
# │  Creative Writer                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  6fca1d8f-54fd-4b42-968c-7896037c01e5                                                                           │
# │  Final Output: The future of electric vehicles is accelerating into an exciting new era, particularly in 2026!  │
# │  Get ready for groundbreaking innovations as over 30 new EVs are set to launch in the U.S. that year. Iconic    │
# │  brands are joining the charge, with Ferrari debuting its first fully electric car in early 2026. Battery       │
# │  technology is rapidly improving, promising impressive range figures, with some new models expected to reach    │
# │  up to 400 miles on a single charge. Even familiar names are getting a futuristic makeover, like the 2026 BMW   │
# │  i3, reimagined as a sleek small sedan built on the innovative Neue Klasse platform. The EV landscape is        │
# │  transforming rapidly!                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw='The future of electric vehicles is accelerating into an exciting new era, particularly in 2026! Get ready for groundbreaking innovations as over 30 new EVs are set to launch in the U.S. that year. Iconic brands are joining the charge, with Ferrari debuting its first fully electric car in early 2026. Battery technology is rapidly improving, promising impressive range figures, with some new models expected to reach up to 400 miles on a single charge. Even familiar names are getting a futuristic makeover, like the 2026 BMW i3, reimagined as a sleek small sedan built on the innovative Neue Klasse platform. The EV landscape is transforming rapidly!', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='*   Ferrari is set to debut its first fully electric car in early 2026.\n*   New EV models coming out in 2026 are expected to have impressive range figures, with some estimates extending to 400 miles.\n*   The 2026 BMW i3 will be reimagined as a small sedan, based on the Neue Klasse platform.\n*   EV battery technology is rapidly improving, leading to new models with longer ranges.\n*   Over 30 new EVs are launching in 2026 in the U.S.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic: The future of electrical vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.'}, {'role': 'assistant', 'content': '', 'tool_calls': [{'id': 'call_131120973416544', 'type': 'function', 'function': {'name': 'search_the_internet_with_serper', 'arguments': '{"search_query": "future of electric vehicles 2026 facts"}'}}]}, {'role': 'tool', 'content': '{\'searchParameters\': {\'q\': \'future of electric vehicles 2026 facts\', \'type\': \'search\', \'num\': 10, \'engine\': \'google\'}, \'organic\': [{\'title\': \'Future EVs: Every Electric Vehicle Coming Soon - Car and Driver\', \'link\': \'https://www.caranddriver.com/news/g29994375/future-electric-cars-trucks/\', \'snippet\': \'Ferrari is readying its first fully electric car, which will debut in early 2026. Spy shots show a low-riding but crossover-like profile, and ...\', \'position\': 1}, {\'title\': \'The 16 Best EVs Coming in 2026 - WIRED\', \'link\': \'https://www.wired.com/story/the-16-best-evs-coming-in-2026/\', \'snippet\': \'Range figures are impressive, with estimates extending to 400 miles. But how does it go? Fast: 1,133 hp and 0 to 62 mph in around 2.5 seconds, ...\', \'position\': 2}, {\'title\': \'Upcoming Electric Cars: 2026-2030 EVs | U.S. News\', \'link\': \'https://cars.usnews.com/cars-trucks/advice/future-electric-cars\', \'snippet\': \'The 2026 i3 is going to be reimagined as a small sedan, based on the Neue Klasse platform, which was showcased in a bold concept car in early 2023.\', \'position\': 3}, {\'title\': \'3 Things You Should Know About EVs in 2026\', \'link\': \'https://whatissmartenergy.org/energy-blog/3-things-you-should-know-about-evs-in-2026\', \'snippet\': \'Worried about running out of power on a long trip? Good news: EV battery technology is improving fast. New models are coming out with longer ranges, letting ...\', \'position\': 4}, {\'title\': \'Electric Vehicles Have a Bumpy Road Ahead in 2026 - Bloomberg\', \'link\':  ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ERROR:crewai.telemetry.telemetry:HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<HTTPSConnection(host='telemetry.crewai.com', port=4319) at 0x77411446a830>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# ERROR:crewai.telemetry.telemetry:HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<HTTPSConnection(host='telemetry.crewai.com', port=4319) at 0x7740fb075ab0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
