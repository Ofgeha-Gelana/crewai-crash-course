# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  3225bfa2-49ad-47c7-8916-cbe44bd4d265                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  ID: d76fc8b1-a04a-431a-8817-27a90b673b14                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about the future of electrical vehicles:                               │
# │                                                                                                                 │
# │  *   **Rapid Market Expansion:** The International Energy Agency (IEA) projects that global electric car sales  │
# │  will reach 17 million in 2024, meaning over one in five cars sold worldwide will be electric. This marks a     │
# │  significant increase from 14 million sales in 2023, highlighting an accelerating pace of adoption.             │
# │  *   **Game-Changing Battery Technology:** Solid-state batteries are on the horizon, promising to               │
# │  revolutionize EV performance. Companies like Toyota are aiming for commercialization by 2027-2028, with        │
# │  potential for a 10-minute charge time to achieve a range of up to 745 miles (1,200 km), significantly          │
# │  surpassing current lithium-ion capabilities.                                                                   │
# │  *   **Vehicles as Grid Assets:** Vehicle-to-Grid (V2G) technology is emerging as a crucial feature, allowing   │
# │  electric vehicles to not only draw power from the grid but also feed electricity back into it. This            │
# │  capability can help stabilize energy grids, especially with increased renewable energy sources, and            │
# │  potentially offer financial incentives to EV owners.                                                           │
# │  *   **Approaching Cost Parity:** The total cost of ownership for electric vehicles is rapidly approaching,     │
# │  and in some cases already surpassing, that of comparable internal combustion engine (ICE) vehicles. Driven by  │
# │  falling battery costs and economies of scale, EVs are expected to reach upfront price parity with ICE          │
# │  vehicles in several segments within the next few years, even without subsidies.                                │
# │  *   **Electrification Beyond Passenger Cars:** The future of EVs extends far beyond consumer passenger         │
# │  vehicles. Significant advancements and investments are being made in electrifying heavy-duty trucks,           │
# │  commercial vans, buses, and even construction equipment, promising substantial reductions in emissions and     │
# │  operational costs across various industries.                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Find 3-5 interesting and recent facts about The future of electrical vehicles.                                 │
# │  Agent:                                                                                                         │
# │  Research Specialist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: 5ad5cc2c-e1b7-4597-8eb4-b5d0fec18ecc                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is accelerating rapidly! Global sales are projected to hit 17 million in       │
# │  2024, showcasing immense market expansion. Revolutionary solid-state batteries, targeting 2027-2028, promise   │
# │  game-changing 10-minute charges for 745 miles. Beyond passenger cars, electrification extends to heavy-duty    │
# │  trucks and commercial fleets. EVs are also becoming vital grid assets via Vehicle-to-Grid (V2G) technology,    │
# │  stabilizing energy networks. With total cost of ownership already competitive and upfront price parity         │
# │  approaching, EVs are poised to redefine our transportation landscape.                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Write a 100-word blog post summary about The future of electrical vehicles using the facts from the research.  │
# │  Agent:                                                                                                         │
# │  Creative Writer                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  3225bfa2-49ad-47c7-8916-cbe44bd4d265                                                                           │
# │  Final Output: The future of electric vehicles is accelerating rapidly! Global sales are projected to hit 17    │
# │  million in 2024, showcasing immense market expansion. Revolutionary solid-state batteries, targeting           │
# │  2027-2028, promise game-changing 10-minute charges for 745 miles. Beyond passenger cars, electrification       │
# │  extends to heavy-duty trucks and commercial fleets. EVs are also becoming vital grid assets via                │
# │  Vehicle-to-Grid (V2G) technology, stabilizing energy networks. With total cost of ownership already            │
# │  competitive and upfront price parity approaching, EVs are poised to redefine our transportation landscape.     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='The future of electric vehicles is accelerating rapidly! Global sales are projected to hit 17 million in 2024, showcasing immense market expansion. Revolutionary solid-state batteries, targeting 2027-2028, promise game-changing 10-minute charges for 745 miles. Beyond passenger cars, electrification extends to heavy-duty trucks and commercial fleets. EVs are also becoming vital grid assets via Vehicle-to-Grid (V2G) technology, stabilizing energy networks. With total cost of ownership already competitive and upfront price parity approaching, EVs are poised to redefine our transportation landscape.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='Here are 5 interesting and recent facts about the future of electrical vehicles:\n\n*   **Rapid Market Expansion:** The International Energy Agency (IEA) projects that global electric car sales will reach 17 million in 2024, meaning over one in five cars sold worldwide will be electric. This marks a significant increase from 14 million sales in 2023, highlighting an accelerating pace of adoption.\n*   **Game-Changing Battery Technology:** Solid-state batteries are on the horizon, promising to revolutionize EV performance. Companies like Toyota are aiming for commercialization by 2027-2028, with potential for a 10-minute charge time to achieve a range of up to 745 miles (1,200 km), significantly surpassing current lithium-ion capabilities.\n*   **Vehicles as Grid Assets:** Vehicle-to-Grid (V2G) technology is emerging as a crucial feature, allowing electric vehicles to not only draw power from the grid but also feed electricity back into it. This capability can help stabilize energy grids, especially with increased renewable energy sources, and potentially offer financial incentives to EV owners.\n*   **Approaching Cost Parity:** The total cost of ownership for electric vehicles is rapidly approaching, and in some cases already surpassing, that of comparable internal combustion engine (ICE) vehicles. Driven by falling battery costs and economies of scale, EVs are expected to reach upfront price parity with ICE vehicles in several segments within the next few years, even without subsidies.\n*   **Electrification Beyond Passenger Cars:** The future of EVs extends far beyond consumer passenger vehicles. Significant advancements and investments are being made in electrifying heavy-duty trucks, commercial vans, buses, and even construction equipment, promising substantial reductions in emissions and operational costs across various industries.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic: The future of electrical vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': 'Here are 5 interesting and recent facts about the future of electrical vehicles:\n\n*   **Rapid Market Expansion:** The International Energy Agency (IEA) projects that global electric car sales will reach 17 million in 2024, meaning over one in five cars sold worldwide will be electric. This marks a significant increase from 14 million sales in 2023, highlighting an accelerating pace of adoption.\n*   **Game-Changing Battery Technology:** Solid-state b ...
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ╭────────────────────────── Tracing Preference Saved ──────────────────────────╮
# │                                                                              │
# │  Info: Tracing has been disabled.                                            │
# │                                                                              │
# │  Your preference has been saved. Future Crew/Flow executions will not        │
# │  collect traces.                                                             │
# │                                                                              │
# │  To enable tracing later, do any one of these:                               │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<HTTPSConnection(host='telemetry.crewai.com', port=4319) at 0x7f71aed558d0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<HTTPSConnection(host='telemetry.crewai.com', port=4319) at 0x7f71aec11630>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
