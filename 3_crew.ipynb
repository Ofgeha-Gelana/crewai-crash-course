# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[37], line 7
#       1 crew = Crew(
#       2     agents=[research_agent, writer_agent],
#       3     tasks=[task1, task2],
#       4     verbose=True,
#       5 )
# ----> 7 crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:743, in Crew.kickoff(self, inputs, input_files)
#     742 if self.process == Process.sequential:
# --> 743     result = self._run_sequential_process()
#     744 elif self.process == Process.hierarchical:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1150, in Crew._run_sequential_process(self)
#    1149 """Executes tasks sequentially and returns the final output."""
# -> 1150 return self._execute_tasks(self.tasks)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1236, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1235 context = self._get_context(task, task_outputs)
# -> 1236 task_output = task.execute_sync(
#    1237     agent=exec_data.agent,
#    1238     context=context,
#    1239     tools=exec_data.tools,
#    1240 )
#    1241 task_outputs.append(task_output)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:499, in Task.execute_sync(self, agent, context, tools)
#     498 """Execute the task synchronously."""
# --> 499 return self._execute_core(agent, context, tools)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:740, in Task._execute_core(self, agent, context, tools)
#     739     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 740     raise e  # Re-raise the exception after emitting the event
#     741 finally:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:671, in Task._execute_core(self, agent, context, tools)
#     670 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 671 result = agent.execute_task(
#     672     task=self,
#     673     context=context,
#     674     tools=tools,
#     675 )
#     677 if not self._guardrails and not self._guardrail:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:492, in Agent.execute_task(self, task, context, tools)
#     484     crewai_event_bus.emit(
#     485         self,
#     486         event=AgentExecutionErrorEvent(
#    (...)
#     490         ),
#     491     )
# --> 492     raise e
#     493 result = self.execute_task(task, context, tools)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:459, in Agent.execute_task(self, task, context, tools)
#     458     else:
# --> 459         result = self._execute_without_timeout(task_prompt, task)
#     461 except TimeoutError as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:568, in Agent._execute_without_timeout(self, task_prompt, task)
#     566     raise RuntimeError("Agent executor is not initialized.")
# --> 568 return self.agent_executor.invoke(
#     569     {
#     570         "input": task_prompt,
#     571         "tool_names": self.agent_executor.tools_names,
#     572         "tools": self.agent_executor.tools_description,
#     573         "ask_for_human_input": task.human_input,
#     574     }
#     575 )["output"]
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:207, in CrewAgentExecutor.invoke(self, inputs)
#     206 try:
# --> 207     formatted_answer = self._invoke_loop()
#     208 except AssertionError:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:308, in CrewAgentExecutor._invoke_loop(self)
#     307 # Fall back to ReAct text-based pattern
# --> 308 return self._invoke_loop_react()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:442, in CrewAgentExecutor._invoke_loop_react(self)
#     441     handle_unknown_error(self._printer, e, verbose=self.agent.verbose)
# --> 442     raise e
#     443 finally:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:337, in CrewAgentExecutor._invoke_loop_react(self)
#     335 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 337 answer = get_llm_response(
#     338     llm=self.llm,
#     339     messages=self.messages,
#     340     callbacks=self.callbacks,
#     341     printer=self._printer,
#     342     from_task=self.task,
#     343     from_agent=self.agent,
#     344     response_model=self.response_model,
#     345     executor_context=self,
#     346     verbose=self.agent.verbose,
#     347 )
#     348 # breakpoint()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:372, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     371 except Exception as e:
# --> 372     raise e
#     373 if not answer:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:362, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     361 try:
# --> 362     answer = llm.call(
#     363         messages,
#     364         tools=tools,
#     365         callbacks=callbacks,
#     366         available_functions=available_functions,
#     367         from_task=from_task,
#     368         from_agent=from_agent,  # type: ignore[arg-type]
#     369         response_model=response_model,
#     370     )
#     371 except Exception as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:331, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     322         return self._handle_streaming_completion(
#     323             formatted_content,
#     324             config,
#    (...)
#     328             effective_response_model,
#     329         )
# --> 331     return self._handle_completion(
#     332         formatted_content,
#     333         config,
#     334         available_functions,
#     335         from_task,
#     336         from_agent,
#     337         effective_response_model,
#     338     )
#     340 except APIError as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1110, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1109         raise LLMContextLengthExceededError(str(e)) from e
# -> 1110     raise e from e
#    1112 self._track_token_usage_internal(usage)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1099, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1098 contents_for_api: Any = contents
# -> 1099 response = self.client.models.generate_content(
#    1100     model=self.model,
#    1101     contents=contents_for_api,
#    1102     config=config,
#    1103 )
#    1105 usage = self._extract_token_usage(response)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:5056, in Models.generate_content(self, model, contents, config)
#    5055 i += 1
# -> 5056 response = self._generate_content(
#    5057     model=model, contents=contents, config=parsed_config
#    5058 )
#    5060 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:3843, in Models._generate_content(self, model, contents, config)
#    3841 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3843 response = self._api_client.request(
#    3844     'post', path, request_dict, http_options
#    3845 )
#    3847 if config is not None and getattr(
#    3848     config, 'should_return_http_response', None
#    3849 ):
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1328 http_request = self._build_request(
#    1329     http_method, path, request_dict, http_options
#    1330 )
# -> 1331 response = self._request(http_request, http_options, stream=False)
#    1332 response_body = (
#    1333     response.response_stream[0] if response.response_stream else ''
#    1334 )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1144, in BaseApiClient._request_once(self, http_request, stream)
#    1137 response = self._httpx_client.request(
#    1138     method=http_request.method,
#    1139     url=http_request.url,
#    (...)
#    1142     timeout=http_request.timeout,
#    1143 )
# -> 1144 errors.APIError.raise_for_response(response)
#    1145 return HttpResponse(
#    1146     response.headers, response if stream else [response.text]
#    1147 )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/errors.py:108, in APIError.raise_for_response(cls, response)
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[37], line 7
#       1 crew = Crew(
#       2     agents=[research_agent, writer_agent],
#       3     tasks=[task1, task2],
#       4     verbose=True,
#       5 )
# ----> 7 crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:743, in Crew.kickoff(self, inputs, input_files)
#     742 if self.process == Process.sequential:
# --> 743     result = self._run_sequential_process()
#     744 elif self.process == Process.hierarchical:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1150, in Crew._run_sequential_process(self)
#    1149 """Executes tasks sequentially and returns the final output."""
# -> 1150 return self._execute_tasks(self.tasks)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1236, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1235 context = self._get_context(task, task_outputs)
# -> 1236 task_output = task.execute_sync(
#    1237     agent=exec_data.agent,
#    1238     context=context,
#    1239     tools=exec_data.tools,
#    1240 )
#    1241 task_outputs.append(task_output)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:499, in Task.execute_sync(self, agent, context, tools)
#     498 """Execute the task synchronously."""
# --> 499 return self._execute_core(agent, context, tools)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:740, in Task._execute_core(self, agent, context, tools)
#     739     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 740     raise e  # Re-raise the exception after emitting the event
#     741 finally:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:671, in Task._execute_core(self, agent, context, tools)
#     670 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 671 result = agent.execute_task(
#     672     task=self,
#     673     context=context,
#     674     tools=tools,
#     675 )
#     677 if not self._guardrails and not self._guardrail:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:492, in Agent.execute_task(self, task, context, tools)
#     484     crewai_event_bus.emit(
#     485         self,
#     486         event=AgentExecutionErrorEvent(
#    (...)
#     490         ),
#     491     )
# --> 492     raise e
#     493 result = self.execute_task(task, context, tools)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:459, in Agent.execute_task(self, task, context, tools)
#     458     else:
# --> 459         result = self._execute_without_timeout(task_prompt, task)
#     461 except TimeoutError as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:568, in Agent._execute_without_timeout(self, task_prompt, task)
#     566     raise RuntimeError("Agent executor is not initialized.")
# --> 568 return self.agent_executor.invoke(
#     569     {
#     570         "input": task_prompt,
#     571         "tool_names": self.agent_executor.tools_names,
#     572         "tools": self.agent_executor.tools_description,
#     573         "ask_for_human_input": task.human_input,
#     574     }
#     575 )["output"]
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:207, in CrewAgentExecutor.invoke(self, inputs)
#     206 try:
# --> 207     formatted_answer = self._invoke_loop()
#     208 except AssertionError:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:308, in CrewAgentExecutor._invoke_loop(self)
#     307 # Fall back to ReAct text-based pattern
# --> 308 return self._invoke_loop_react()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:442, in CrewAgentExecutor._invoke_loop_react(self)
#     441     handle_unknown_error(self._printer, e, verbose=self.agent.verbose)
# --> 442     raise e
#     443 finally:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:337, in CrewAgentExecutor._invoke_loop_react(self)
#     335 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 337 answer = get_llm_response(
#     338     llm=self.llm,
#     339     messages=self.messages,
#     340     callbacks=self.callbacks,
#     341     printer=self._printer,
#     342     from_task=self.task,
#     343     from_agent=self.agent,
#     344     response_model=self.response_model,
#     345     executor_context=self,
#     346     verbose=self.agent.verbose,
#     347 )
#     348 # breakpoint()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:372, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     371 except Exception as e:
# --> 372     raise e
#     373 if not answer:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:362, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     361 try:
# --> 362     answer = llm.call(
#     363         messages,
#     364         tools=tools,
#     365         callbacks=callbacks,
#     366         available_functions=available_functions,
#     367         from_task=from_task,
#     368         from_agent=from_agent,  # type: ignore[arg-type]
#     369         response_model=response_model,
#     370     )
#     371 except Exception as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:331, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     322         return self._handle_streaming_completion(
#     323             formatted_content,
#     324             config,
#    (...)
#     328             effective_response_model,
#     329         )
# --> 331     return self._handle_completion(
#     332         formatted_content,
#     333         config,
#     334         available_functions,
#     335         from_task,
#     336         from_agent,
#     337         effective_response_model,
#     338     )
#     340 except APIError as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1110, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1109         raise LLMContextLengthExceededError(str(e)) from e
# -> 1110     raise e from e
#    1112 self._track_token_usage_internal(usage)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1099, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1098 contents_for_api: Any = contents
# -> 1099 response = self.client.models.generate_content(
#    1100     model=self.model,
#    1101     contents=contents_for_api,
#    1102     config=config,
#    1103 )
#    1105 usage = self._extract_token_usage(response)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:5056, in Models.generate_content(self, model, contents, config)
#    5055 i += 1
# -> 5056 response = self._generate_content(
#    5057     model=model, contents=contents, config=parsed_config
#    5058 )
#    5060 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:3843, in Models._generate_content(self, model, contents, config)
#    3841 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3843 response = self._api_client.request(
#    3844     'post', path, request_dict, http_options
#    3845 )
#    3847 if config is not None and getattr(
#    3848     config, 'should_return_http_response', None
#    3849 ):
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1328 http_request = self._build_request(
#    1329     http_method, path, request_dict, http_options
#    1330 )
# -> 1331 response = self._request(http_request, http_options, stream=False)
#    1332 response_body = (
#    1333     response.response_stream[0] if response.response_stream else ''
#    1334 )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1144, in BaseApiClient._request_once(self, http_request, stream)
#    1137 response = self._httpx_client.request(
#    1138     method=http_request.method,
#    1139     url=http_request.url,
#    (...)
#    1142     timeout=http_request.timeout,
#    1143 )
# -> 1144 errors.APIError.raise_for_response(response)
#    1145 return HttpResponse(
#    1146     response.headers, response if stream else [response.text]
#    1147 )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/errors.py:108, in APIError.raise_for_response(cls, response)
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[37], line 7
#       1 crew = Crew(
#       2     agents=[research_agent, writer_agent],
#       3     tasks=[task1, task2],
#       4     verbose=True,
#       5 )
# ----> 7 crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:743, in Crew.kickoff(self, inputs, input_files)
#     740 inputs = prepare_kickoff(self, inputs, input_files)
#     742 if self.process == Process.sequential:
# --> 743     result = self._run_sequential_process()
#     744 elif self.process == Process.hierarchical:
#     745     result = self._run_hierarchical_process()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1150, in Crew._run_sequential_process(self)
#    1148 def _run_sequential_process(self) -> CrewOutput:
#    1149     """Executes tasks sequentially and returns the final output."""
# -> 1150     return self._execute_tasks(self.tasks)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/crew.py:1236, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1233     futures.clear()
#    1235 context = self._get_context(task, task_outputs)
# -> 1236 task_output = task.execute_sync(
#    1237     agent=exec_data.agent,
#    1238     context=context,
#    1239     tools=exec_data.tools,
#    1240 )
#    1241 task_outputs.append(task_output)
#    1242 self._process_task_result(task, task_output)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:499, in Task.execute_sync(self, agent, context, tools)
#     492 def execute_sync(
#     493     self,
#     494     agent: BaseAgent | None = None,
#     495     context: str | None = None,
#     496     tools: list[BaseTool] | None = None,
#     497 ) -> TaskOutput:
#     498     """Execute the task synchronously."""
# --> 499     return self._execute_core(agent, context, tools)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:740, in Task._execute_core(self, agent, context, tools)
#     738     self.end_time = datetime.datetime.now()
#     739     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 740     raise e  # Re-raise the exception after emitting the event
#     741 finally:
#     742     clear_task_files(self.id)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/task.py:671, in Task._execute_core(self, agent, context, tools)
#     669 self.processed_by_agents.add(agent.role)
#     670 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 671 result = agent.execute_task(
#     672     task=self,
#     673     context=context,
#     674     tools=tools,
#     675 )
#     677 if not self._guardrails and not self._guardrail:
#     678     pydantic_output, json_output = self._export_output(result)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     484         crewai_event_bus.emit(
#     485             self,
#     486             event=AgentExecutionErrorEvent(
#    (...)
#     490             ),
#     491         )
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#     496     self._rpm_controller.stop_rpm_counter()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:493, in Agent.execute_task(self, task, context, tools)
#     484         crewai_event_bus.emit(
#     485             self,
#     486             event=AgentExecutionErrorEvent(
#    (...)
#     490             ),
#     491         )
#     492         raise e
# --> 493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#     496     self._rpm_controller.stop_rpm_counter()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:492, in Agent.execute_task(self, task, context, tools)
#     483     if self._times_executed > self.max_retry_limit:
#     484         crewai_event_bus.emit(
#     485             self,
#     486             event=AgentExecutionErrorEvent(
#    (...)
#     490             ),
#     491         )
# --> 492         raise e
#     493     result = self.execute_task(task, context, tools)
#     495 if self.max_rpm and self._rpm_controller:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:459, in Agent.execute_task(self, task, context, tools)
#     455         result = self._execute_with_timeout(
#     456             task_prompt, task, self.max_execution_time
#     457         )
#     458     else:
# --> 459         result = self._execute_without_timeout(task_prompt, task)
#     461 except TimeoutError as e:
#     462     crewai_event_bus.emit(
#     463         self,
#     464         event=AgentExecutionErrorEvent(
#    (...)
#     468         ),
#     469     )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agent/core.py:568, in Agent._execute_without_timeout(self, task_prompt, task)
#     565 if not self.agent_executor:
#     566     raise RuntimeError("Agent executor is not initialized.")
# --> 568 return self.agent_executor.invoke(
#     569     {
#     570         "input": task_prompt,
#     571         "tool_names": self.agent_executor.tools_names,
#     572         "tools": self.agent_executor.tools_description,
#     573         "ask_for_human_input": task.human_input,
#     574     }
#     575 )["output"]
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:207, in CrewAgentExecutor.invoke(self, inputs)
#     204 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     206 try:
# --> 207     formatted_answer = self._invoke_loop()
#     208 except AssertionError:
#     209     if self.agent.verbose:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:308, in CrewAgentExecutor._invoke_loop(self)
#     305     return self._invoke_loop_native_tools()
#     307 # Fall back to ReAct text-based pattern
# --> 308 return self._invoke_loop_react()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:442, in CrewAgentExecutor._invoke_loop_react(self)
#     440         continue
#     441     handle_unknown_error(self._printer, e, verbose=self.agent.verbose)
# --> 442     raise e
#     443 finally:
#     444     self.iterations += 1
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:337, in CrewAgentExecutor._invoke_loop_react(self)
#     333     break
#     335 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 337 answer = get_llm_response(
#     338     llm=self.llm,
#     339     messages=self.messages,
#     340     callbacks=self.callbacks,
#     341     printer=self._printer,
#     342     from_task=self.task,
#     343     from_agent=self.agent,
#     344     response_model=self.response_model,
#     345     executor_context=self,
#     346     verbose=self.agent.verbose,
#     347 )
#     348 # breakpoint()
#     349 if self.response_model is not None:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:372, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     362     answer = llm.call(
#     363         messages,
#     364         tools=tools,
#    (...)
#     369         response_model=response_model,
#     370     )
#     371 except Exception as e:
# --> 372     raise e
#     373 if not answer:
#     374     if verbose:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:362, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     359     messages = executor_context.messages
#     361 try:
# --> 362     answer = llm.call(
#     363         messages,
#     364         tools=tools,
#     365         callbacks=callbacks,
#     366         available_functions=available_functions,
#     367         from_task=from_task,
#     368         from_agent=from_agent,  # type: ignore[arg-type]
#     369         response_model=response_model,
#     370     )
#     371 except Exception as e:
#     372     raise e
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:331, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     321     if self.stream:
#     322         return self._handle_streaming_completion(
#     323             formatted_content,
#     324             config,
#    (...)
#     328             effective_response_model,
#     329         )
# --> 331     return self._handle_completion(
#     332         formatted_content,
#     333         config,
#     334         available_functions,
#     335         from_task,
#     336         from_agent,
#     337         effective_response_model,
#     338     )
#     340 except APIError as e:
#     341     error_msg = f"Google Gemini API error: {e.code} - {e.message}"
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1110, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1108         logging.error(f"Context window exceeded: {e}")
#    1109         raise LLMContextLengthExceededError(str(e)) from e
# -> 1110     raise e from e
#    1112 self._track_token_usage_internal(usage)
#    1114 return self._process_response_with_tools(
#    1115     response=response,
#    1116     contents=contents,
#    (...)
#    1120     response_model=response_model,
#    1121 )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/crewai/llms/providers/gemini/completion.py:1099, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1096 try:
#    1097     # The API accepts list[Content] but mypy is overly strict about variance
#    1098     contents_for_api: Any = contents
# -> 1099     response = self.client.models.generate_content(
#    1100         model=self.model,
#    1101         contents=contents_for_api,
#    1102         config=config,
#    1103     )
#    1105     usage = self._extract_token_usage(response)
#    1106 except Exception as e:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:5056, in Models.generate_content(self, model, contents, config)
#    5054 while remaining_remote_calls_afc > 0:
#    5055   i += 1
# -> 5056   response = self._generate_content(
#    5057       model=model, contents=contents, config=parsed_config
#    5058   )
#    5060   function_map = _extra_utils.get_function_map(parsed_config)
#    5061   if not function_map:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/models.py:3843, in Models._generate_content(self, model, contents, config)
#    3840 request_dict = _common.convert_to_dict(request_dict)
#    3841 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3843 response = self._api_client.request(
#    3844     'post', path, request_dict, http_options
#    3845 )
#    3847 if config is not None and getattr(
#    3848     config, 'should_return_http_response', None
#    3849 ):
#    3850   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1321 def request(
#    1322     self,
#    1323     http_method: str,
#    (...)
#    1326     http_options: Optional[HttpOptionsOrDict] = None,
#    1327 ) -> SdkHttpResponse:
#    1328   http_request = self._build_request(
#    1329       http_method, path, request_dict, http_options
#    1330   )
# -> 1331   response = self._request(http_request, http_options, stream=False)
#    1332   response_body = (
#    1333       response.response_stream[0] if response.response_stream else ''
#    1334   )
#    1335   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1164     retry = tenacity.Retrying(**retry_kwargs)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/_api_client.py:1144, in BaseApiClient._request_once(self, http_request, stream)
#    1136 else:
#    1137   response = self._httpx_client.request(
#    1138       method=http_request.method,
#    1139       url=http_request.url,
#    (...)
#    1142       timeout=http_request.timeout,
#    1143   )
# -> 1144   errors.APIError.raise_for_response(response)
#    1145   return HttpResponse(
#    1146       response.headers, response if stream else [response.text]
#    1147   )
#
# File ~/Desktop/crewai-tutorial/.venv/lib/python3.10/site-packages/google/genai/errors.py:108, in APIError.raise_for_response(cls, response)
#     106 status_code = response.status_code
#     107 if 400 <= status_code < 500:
# --> 108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
#     110   raise ServerError(status_code, response_json, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}
